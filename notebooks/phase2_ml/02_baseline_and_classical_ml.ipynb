# %% [markdown]
# # Phase 2 — Baseline and Classical ML
#
# Scaffold notebook for baseline + classical algorithms.
#
# Config: `configs/phase2/ml_experiment.yaml`

# %%
print("Phase 2 classical ML scaffold")
