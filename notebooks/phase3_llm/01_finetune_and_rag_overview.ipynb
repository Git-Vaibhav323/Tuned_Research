# %% [markdown]
# # Phase 3 — Fine-tuning and RAG Overview
#
# Scaffold notebook for instruction data prep, retrieval experiments, and dashboard integration notes.
#
# - `configs/phase3/finetune.yaml`
# - `configs/phase3/rag.yaml`
# - `configs/phase3/dashboard.yaml`

# %%
print("Phase 3 fine-tuning / RAG scaffold")
