# %% [markdown]
# # Phase 1 — Data Collection Overview
#
# Scaffold notebook. Implement dataset source review, schema inspection, and license notes here.
#
# - Config: `configs/phase1/data_collection.yaml`
# - Raw paths: `data/raw/`, `data/external/`, `data/raw_papers/`
# - Metadata: `data/metadata/`

# %%
# TODO: load and profile collected data
print("Phase 1 collection notebook scaffold")
